# %% [markdown]
# # Interactive Linguistic Essay

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# #### In this essay, we will use **Python** libraries such as *Beautiful Soup* for web scraping and *NLTK* for basic linguistic analysis. We will demonstrate how to extract text from a website and perform some simple analyses on the collected data.

# %% [markdown]
# ![Astronauts](https://cdn.mos.cms.futurecdn.net/2oNNWzMiyntgoVjmedmpdn.jpg)

# %% [markdown]
# ## **Web Scraping with** ***Beautiful Soup***

# %% [markdown]
# #### Using *Beautiful Soup*, you can extract a section of a webpage!

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://aerospace.org/article/brief-history-space-exploration'
response = requests.get(url)
html = response.text

soup = BeautifulSoup(html, 'html.parser')
div_body = soup.find('div', class_='field__body')
paragraphs = div_body.find_all('p')
text = ' '.join([p.get_text() for p in paragraphs])

print(text[:222])
# Out:
# Humans have always looked up into the night sky and dreamed about space. In the latter half of the 20th century, rockets were developed that were powerful enough to overcome the force of gravity to reach orbital velocities

# %% [markdown]
# #### In the example above the we display the first 222 characters.

# %% [markdown]
# ## **The amazing power of** ***NLTK***

# %% [markdown]
# #### *NLTK* is a leading platform for building **Python** programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as *WordNet*, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum.

# %% [markdown]
# #### By using *NLTK* we can split our text into separated words and then using *matplotlib* we can display various features such as their distribution chart.

# %% [markdown]
# #### Let's start with spliting the previously downloaded text into words.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist
import matplotlib.pyplot as plt

words = word_tokenize(text)
sentences = sent_tokenize(text)

# %% [markdown]
# #### We can also divide the text into sentences by using the code below.

# %%
sentences = sent_tokenize(text)
print(sentences[:2])
# Out:
# ['Humans have always looked up into the night sky and dreamed about space.', 'In the latter half of the 20th century, rockets were developed that were powerful enough to overcome the force of gravity to reach orbital velocities, paving the way for space exploration to become a reality.']

# %% [markdown]
# #### See? We can also get rid of punctuation marks!

# %%
words = [word.lower() for word in words if word.isalpha()]

# %% [markdown]
# #### What is more, by using the code below, we can display the most frequent words from the text

# %%
fdist = FreqDist(words)

common_words = fdist.most_common(10)
print ("Common words:")
print(common_words)
# Out:
# Common words:
# [('the', 86), ('and', 42), ('of', 36), ('to', 26), ('space', 25), ('in', 20), ('a', 20), ('on', 15), ('shuttle', 15), ('was', 13)]

# %% [markdown]
# #### Below you can see the chart for the results.

# %%
plt.title('Word Frequency Distribution')
fdist.plot(30, cumulative=False)
plt.show()

# %% [markdown]
# #### By using the code below we can get the total number of words from the text.

# %%
print(len(words))
# Out:
# 984

# %% [markdown]
# #### Apart from linguistic tools, **Python** can help us with some _mathematical_ problems by providing immediate solutions.

# %% [markdown]
# #### Below you can see some examples of helpful codes:

# %%
2 + 2
# Out:
# 4

# %%
8 * 8/(6 - 2)
# Out:
# 16.0

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
def area_circle(r):
    return math.pi * r ** 2

# %%
area_circle(1)
# Out:
# 3.141592653589793

# %%
area_circle(9)
# Out:
# 254.46900494077323

# %% [markdown]
# ### There are many more possibilities! I encourage you to try it on your own because it is a very interesting tool. I guarantee you will have so much fun!
